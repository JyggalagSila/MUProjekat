# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

dataframe = pd.read_csv('TestDatasets/genres_v2.csv', low_memory=False)
corr_matrix = dataframe.corr()

plt.figure(figsize=(20,20))
sns.heatmap(corr_matrix, annot=True, cmap='RdBu')
plt.title('Correlation Heatmap', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
dataframe = pd.read_csv('TestDatasets/videogames.csv', low_memory=False)
corr_matrix = dataframe.corr()

plt.figure(figsize=(20,20))
sns.heatmap(corr_matrix, annot=True, cmap='RdBu')
plt.title('Correlation Heatmap', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
dataframe = pd.read_csv('TestDatasets/pokemon.csv', low_memory=False)
corr_matrix = dataframe.corr()

plt.figure(figsize=(20,20))
sns.heatmap(corr_matrix, annot=True, cmap='RdBu')
plt.title('Correlation Heatmap', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
dataframe = pd.read_csv('TestDatasets/football.csv', low_memory=False)
corr_matrix = dataframe.corr()

plt.figure(figsize=(20,20))
sns.heatmap(corr_matrix, annot=True, cmap='RdBu')
plt.title('Correlation Heatmap', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
dataframe = pd.read_csv('TestDatasets/fire.csv', low_memory=False)
corr_matrix = dataframe.corr()

plt.figure(figsize=(20,20))
sns.heatmap(corr_matrix, annot=True, cmap='RdBu')
plt.title('Correlation Heatmap', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
dataframe = pd.read_csv('TestDatasets/astronauts.csv', low_memory=False)
corr_matrix = dataframe.corr()

plt.figure(figsize=(20,20))
sns.heatmap(corr_matrix, annot=True, cmap='RdBu')
plt.title('Correlation Heatmap', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')
